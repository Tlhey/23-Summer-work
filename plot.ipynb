# %% [markdown]
# # below is N 63

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.genfromtxt('csv/1.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])

# %%
y = np.genfromtxt('csv/2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])

# %%
y = np.genfromtxt('csv/3.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])

# %%
y = np.genfromtxt('csv/4.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e1.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# time-Kenetic energy
# dt = 0.000001, e=10, c =25-, b=0

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e1.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=10, c =25-, b=0

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e1.csv', delimiter=',')
plt.scatter(y[:3000,0], y[:3000,1])
# dt = 0.000001, e=10, c =250, b=0

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=10, c =250, b=0

#10000000, 0.000000001

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=10, c =250, b=0

#10000000, 0.000000003

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=10, c =250, b=0

#10000000, 0.00000001

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=10, c =250, b=0

#10000000, 0.000001

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=10, c =250, b=0
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.0000001, e=0, c =250, b=0
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.000001, e=0, c =250, b=0
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.0001, e=0, c =250, b=0
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:20000,0], y[:20000,1])
# dt = 0.000001, e=0, c =250, b=0
# no relaxation

# %% [markdown]
# # below is N changed

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:,0], y[:,1])
# dt = 0.0001, e=0, c =250, b=0, N=255
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:20000,0], y[:20000,1])
# dt = 0.0001, e=0, c =250, b=0, N=1023
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:20000,0], y[:20000,1])
# dt = 0.000001, e=0, c =250, b=0, N=1023
# no relaxation

# %%
import numpy as np
import matplotlib.pyplot as plt
y = np.genfromtxt('csv/e2.csv', delimiter=',')
plt.scatter(y[:20000,0], y[:20000,1])
# dt = 0.0000001, e=0, c =250, b=0, N=1023
# no relaxation
